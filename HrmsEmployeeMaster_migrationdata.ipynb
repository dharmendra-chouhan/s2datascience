# %% [markdown]
# <a href="https://colab.research.google.com/github/dharmendra-chouhan/s2datascience/blob/master/HrmsEmployeeMaster_migrationdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title *Read a Excel file from a Google drive** {display-mode: "form"}
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#2. Get the file Cosolidated sheet for Dec 2019_Annexure-3.xlsx
downloaded = drive.CreateFile({'id':'1ckUBg7piDEXcC4XLChInjkezgA_KUOSO'}) # replace the id with id of file you want to access
downloaded.GetContentFile('HRMS Master Tracker 27_09_2020.xlsx')  


import pandas as pd

# Master Tracker 18_08_2020.xlsx
dfCosolidated_sheet_for_Dec_2019_Annexure_3 =  pd.read_excel('HRMS Master Tracker 27_09_2020.xlsx', sheet_name='Active Employee', skiprows=1)

# %%
#@title *Select Grade / Project** {display-mode: "form"}
import numpy as np
productlist =list(dfCosolidated_sheet_for_Dec_2019_Annexure_3.Grade.unique())
Grade = 'ULB' #@param ['Aadhar','Aaple Sarkar','ADHARDC','AHF','AHM', 'Bharat Net (MBN 2)', 'BPMS', 'BPMS Corp', 'BPMS_ULB', 'CIDCO', 'Citizen Services', 'CRF', 'CS Office 2', 'CST', 'CSVJNT', 'DAT', 'DAT-Finance  Project', 'DBT', 'DCM', 'DIT', 'DIT 2', 'DIT SETU', 'DMA', 'Farm Loan Waiver', 'Farm Loan Waiver 2', 'FCS', 'FCSCP', 'FDA 2', 'FMS', 'HRC', 'HTE Sevaarth', 'Human Right 2', 'IGR', 'IGR033', 'IGR16', 'IGR6', 'IT Minister', 'MADC', 'Maha IT Internal', 'Maha Pariksha', 'Maha Sadan', 'MBN', 'MHADA', 'MIT', 'MIT Chiefdataofficer', 'NIC', 'NIC AGRI', 'NIC Primary Education', 'Panchayat Raj Sevart', 'Plant Projection', 'PMK', 'RDD Saral OTT', 'RDDN', 'Rera Kerala', 'Revenue Forest Dept', 'Sau Sevarth App', 'SESD', 'Sevarth for Ayurveda', 'Sevarth Samaj Sevart', 'Soil Testing', 'Soil Water New', 'UDD', 'ULB', 'VET', 'VJNT', 'WCD628', 'Zilla Parishad', 'Zilla Parishad DPL', 'Home Minister']
df1=dfCosolidated_sheet_for_Dec_2019_Annexure_3[dfCosolidated_sheet_for_Dec_2019_Annexure_3["Grade"] == Grade]

df = pd.DataFrame() 
df[['Old Employee ID *']]=df1[['E Code']]
splitted =  df1['Employee Name'].str.split()
df['Employee First Name (English)*'] = splitted.str[0]
df['Employee Middle Name (English)*'] =  df1['Employee Name'].loc[ df1['Employee Name'].str.split().str.len() == 3].str.split(expand=True)[1]
df['Employee Last Name (English)*'] = splitted.str[-1]
df[['Aadhar No','Pan No']]=df1[['Adhar No','PAN No']]
df['Election card no.']=''
df[['Gender']]=df1[['Gender']]


df[['Date Of Birth *']]=df1[['Date of Birth']]

 

df['Height *']=''
df['Birth Place']=''
df['Blood Group *']=df1[['Blood Group']]
df['Blood Group *'] = df['Blood Group *'].fillna('Other')
df[['maritial Status *']]=df1[['Maritial Status']]
df[['Mobile No. *']]=df1[['Contact No']]
df[['Phone No.']]=df1[['Contact No']]

df['Mobile No. *'] = df['Mobile No. *'].str[:10]



df['Emergency Contact Person Name']=''
df[['Emergency Contact Person Number','Email ID *']]=df1[['Emergency Contact','Email Id ']]
df[['Official Email ID *']]=df1[['Email Id ']]
df['Employee is Physically Disable?']='No'
df['Disability Type']=''
df['Percentage Disability']=''
df[['PF Number *','UAN Number']]=df1[['Pf No ','UAN No ']].astype('str')
df['Hobbies *']='Not Provided'
df['Flat No / House *'], df['Street / Road Name *'] = df1['Local Adress'].str[:50], df1['Local Adress'].str[50:]
df['Flat No / House *'] = df['Flat No / House *']+df['Street / Road Name *'].str.split(',').str.get(0)
df['Street / Road Name *'] = df['Street / Road Name *'].astype('str').map(lambda x: x.lstrip(str(df['Street / Road Name *'].str.split(',').str.get(0))).rstrip(''))
df['Area *']=''
df[['City *','State *']]=df1[['Sub Location','State']]
df['Pincode *']= df1['Local Adress'].str.extract(r'(\d{5}\-?\d{0,6})')
df['Communication Address Same As a Permanent Address?']='Yes'
df['Communication Flat No / House *']=df['Flat No / House *']
df['Communication Street / Road Name *']=df['Street / Road Name *']
df['Communication Area *']=''
df[['Communication City *','Communication State*','Communication Pincode *']]=df[['City *','State *','Pincode *']]
df['Native Address Same As a Permanent Address?']='Yes'

df['Native Flat No / House *']=df['Flat No / House *']
df['Native Street / Road Name *']=df['Street / Road Name *']
df['Native Area *']=''
df[['Native City *','Native State*','Native Pincode *']]=df[['City *','State *','Pincode *']]

   

df['Religion']='Other'
df['Mother Tongue']='English'
df['Caste Employee']='Open'
df['Category']='Project Employee'
df['Appointment / Offer Letter Order No.']=''
df['Appointment / Offer Letter Order Date']=df1[['Offer Date']]
df['Employee Type *']=df1[['Emp Type']]
df['(Taluka)Block *']=df1[['Work Location/District']]
df['Current Department *']='Not Available'
df['Confirmation Order No.']=''
df['Confirmation Order Date']=''
df['Current Designation *']=df1[['Designation']]
df['Current Location *']=df1[['Work Location/District']]
df['Old CTC']=''
df['Date Of Joining *']=df1['DOJ']
df['Retirement Date']=''
df['Previous Organization Behaviour Certificate Given?']='No'

df['Behaviour Order No.']=''
df['Behaviour Order Date']=''
df['Is there Any Department Enquiry']=''
df['Department Enquiry Order No.']=''
df['Department Enquiry Order Date']=''
df['Remark']=''

df['Probation From Date *']=''
df['Probation To Date *']=''
df['Probation Period No. Of Days *']=''
df['Type Separation']=''
df['Date of Separation']=''
df['Gratuity Date']=''
df['Full and Final Settlement Date']=''
df['Bank A/C No *']=df1['Bank Account Number']
df['Bank Name *']=df1['Bank Name']  
df['Bank Branch *']=df1['Branch']  
df['IFSC Code *']=df1['IFSC Code'] 
df['MICR Code']=''
df['Zone']=df1['Work Location/District']   
df['Sub Zone']=df1['Sub Location'] 
df['DCPS No.']=''
df['Total Work Experience']=df1['Total Experience']
df['Payment Processed By']='ECS'
df['Joining Location']=df1['Work Location/District']
df['New CTC']=df1['ANNUAL CTC']  
df['Current State']=df[['State *']]
df['Current City']=df[['City *']]
df['Current location']=df1['Work Location/District']
df['Joining State']=df[['State *']]
df['Joining City']=df1['Sub Location']
df['Joining location 1']=df1['Work Location/District']



df['Date Of Birth *'] =pd.to_datetime(df['Date Of Birth *']).dt.date


df = df.replace('nan',"")

# %%
#@title *Generating an Excel file* {display-mode: "form"}
df.to_excel(Grade+'.xlsx', sheet_name='Personal Details')
from google.colab import files
files.download(Grade+'.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 1484 to 1507
# Data columns (total 93 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Old Employee ID *                                   24 non-null     object
#  1   Employee First Name (English)*                      24 non-null     object
#  2   Employee Middle Name (English)*                     14 non-null     object
#  3   Employee Last Name (English)*                       24 non-null     object
#  4   Aadhar No                                           24 non-null     object
#  5   Pan No                                              24 non-null     object
#  6   Election card no.                                   24 non-null     object
#  7   Gender                                              24 non-null     object
#  8   Date Of Birth *                                     24 non-null     object
#  9   Height *                                            24 non-null     object
#  10  Birth Place                                         24 non-null     object
#  11  Blood Group *                                       24 non-null     object
#  12  maritial Status *                                   24 non-null     object
#  13  Mobile No. *                                        24 non-null     object
#  14  Phone No.                                           24 non-null     object
#  15  Emergency Contact Person Name                       24 non-null     object
#  16  Emergency Contact Person Number                     0 non-null      float64
#  17  Email ID *                                          24 non-null     object
#  18  Official Email ID *                                 24 non-null     object
#  19  Employee is Physically Disable?                     24 non-null     object
#  20  Disability Type                                     24 non-null     object
#  21  Percentage Disability                               24 non-null     object
#  22  PF Number *                                         24 non-null     object
#  23  UAN Number                                          24 non-null     object
#  24  Hobbies *                                           24 non-null     object
#  25  Flat No / House *                                   2 non-null      object
#  26  Street / Road Name *                                24 non-null     object
#  27  Area *                                              24 non-null     object
#  28  City *                                              24 non-null     object
#  29  State *                                             24 non-null     object
#  30  Pincode *                                           0 non-null      float64
#  31  Communication Address Same As a Permanent Address?  24 non-null     object
#  32  Communication Flat No / House *                     2 non-null      object
#  33  Communication Street / Road Name *                  24 non-null     object
#  34  Communication Area *                                24 non-null     object
#  35  Communication City *                                24 non-null     object
#  36  Communication State*                                24 non-null     object
#  37  Communication Pincode *                             0 non-null      float64
#  38  Native Address Same As a Permanent Address?         24 non-null     object
#  39  Native Flat No / House *                            2 non-null      object
#  40  Native Street / Road Name *                         24 non-null     object
#  41  Native Area *                                       24 non-null     object
#  42  Native City *                                       24 non-null     object
#  43  Native State*                                       24 non-null     object
#  44  Native Pincode *                                    0 non-null      float64
#  45  Religion                                            24 non-null     object
#  46  Mother Tongue                                       24 non-null     object
#  47  Caste Employee                                      24 non-null     object
#  48  Category                                            24 non-null     object
#  49  Appointment / Offer Letter Order No.                24 non-null     object
#  50  Appointment / Offer Letter Order Date               22 non-null     object
#  51  Employee Type *                                     24 non-null     object
#  52  (Taluka)Block *                                     24 non-null     object
#  53  Current Department *                                24 non-null     object
#  54  Confirmation Order No.                              24 non-null     object
#  55  Confirmation Order Date                             24 non-null     object
#  56  Current Designation *                               24 non-null     object
#  57  Current Location *                                  24 non-null     object
#  58  Old CTC                                             24 non-null     object
#  59  Date Of Joining *                                   24 non-null     object
#  60  Retirement Date                                     24 non-null     object
#  61  Previous Organization Behaviour Certificate Given?  24 non-null     object
#  62  Behaviour Order No.                                 24 non-null     object
#  63  Behaviour Order Date                                24 non-null     object
#  64  Is there Any Department Enquiry                     24 non-null     object
#  65  Department Enquiry Order No.                        24 non-null     object
#  66  Department Enquiry Order Date                       24 non-null     object
#  67  Remark                                              24 non-null     object
#  68  Probation From Date *                               24 non-null     object
#  69  Probation To Date *                                 24 non-null     object
#  70  Probation Period No. Of Days *                      24 non-null     object
#  71  Type Separation                                     24 non-null     object
#  72  Date of Separation                                  24 non-null     object
#  73  Gratuity Date                                       24 non-null     object
#  74  Full and Final Settlement Date                      24 non-null     object
#  75  Bank A/C No *                                       24 non-null     object
#  76  Bank Name *                                         24 non-null     object
#  77  Bank Branch *                                       24 non-null     object
#  78  IFSC Code *                                         24 non-null     object
#  79  MICR Code                                           24 non-null     object
#  80  Zone                                                24 non-null     object
#  81  Sub Zone                                            24 non-null     object
#  82  DCPS No.                                            24 non-null     object
#  83  Total Work Experience                               11 non-null     float64
#  84  Payment Processed By                                24 non-null     object
#  85  Joining Location                                    24 non-null     object
#  86  New CTC                                             24 non-null     int64
#  87  Current State                                       24 non-null     object
#  88  Current City                                        24 non-null     object
#  89  Current location                                    24 non-null     object
#  90  Joining State                                       24 non-null     object
#  91  Joining City                                        24 non-null     object
#  92  Joining location 1                                  24 non-null     object
# dtypes: float64(5), int64(1), object(87)
# memory usage: 17.6+ KB
